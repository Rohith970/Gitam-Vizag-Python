# %% [markdown]
# ### MINI PROJECT on IPL DataSet

# %%
import pandas as pd
filepath='DataFile/Match.csv'
def readCsvData(filepath):
    return pd.read_csv(filepath)
df1=readCsvData(filepath)
print(readCsvData(filepath))
# Out:
#      Match_SK  match_id                        Team1  \
# 0           0    335987  Royal Challengers Bangalore
# 1           1    335988              Kings XI Punjab
# 2           2    335989             Delhi Daredevils
# 3           3    335990               Mumbai Indians
# 4           4    335991        Kolkata Knight Riders
# 5           5    335992             Rajasthan Royals
# 6           6    335993              Deccan Chargers
# 7           7    335994          Chennai Super Kings
# 8           8    335995              Deccan Chargers
# 9           9    335996              Kings XI Punjab
# 10         10    335997  Royal Challengers Bangalore
# 11         11    335998          Chennai Super Kings
# 12         12    335999               Mumbai Indians
# 13         13    336000              Kings XI Punjab
# 14         14    336001  Royal Challengers Bangalore
# 15         15    336002        Kolkata Knight Riders
# 16         16    336003             Delhi Daredevils
# ...

# %% [markdown]
# ### 1) Display the count of matches based on Year Wise

# %% [markdown]
# ### Description of the problem
# - importing the required packages
# - use the group by statement
# - use the count function

# %%
pd.DataFrame(df1.groupby('Season_Year')['Match_SK'].count())
#df1.columns.tolist()
# Out:
#              Match_SK
# Season_Year
# 2008               58
# 2009               57
# 2010               60
# 2011               73
# 2012               74
# 2013               76
# 2014               60
# 2015               59
# 2016               60
# 2017               60

# %% [markdown]
# ### 2) plot a bar graph no of matches won by each team in the year 2011

# %% [markdown]
# ### Description of the problem
# - import all the packages
# - declare a list that consists of values
# - then equalize and sort out the given dataset with the list
# - now get the values of each team winners
# - then write the code for displaing the bar graph

# %%
import numpy as np
value_list = [2011]
new_df = df1[df1.Season_Year.isin(value_list)]
new_df
wins=(new_df.groupby('match_winner')['Match_SK'].count())

df2=new_df.Team1.unique()
df2
index=np.arange(len(df2))
pd.DataFrame(new_df.groupby("Team1")["match_winner"].count())
plt.barh(df2,wins,color='Blue')
width=0.5

# %% [markdown]
# ### 3) Print the Man of The match of each player in hyd stadium

# %% [markdown]
# ### Description of the problem
# - import all the packages
# - declare a list that consists of values
# - then equalize and sort out the given dataset with the list
# - display the man of the matches and their count

# %%
df3=df1.copy()
new_df1=pd.DataFrame(df3[df3['City_Name'].isin(['Hyderabad'])])
pd.DataFrame(new_df1.groupby('ManOfMach')['Match_SK'].count())
# Out:
#                    Match_SK
# ManOfMach
# A Mishra                  2
# AB Dinda                  1
# AT Rayudu                 1
# B Kumar                   1
# CH Morris                 1
# DA Warner                 6
# DJ Bravo                  1
# DJG Sammy                 1
# DW Steyn                  3
# G Gambhir                 1
# GH Vihari                 2
# I Sharma                  1
# MJ McClenaghan            1
# MR Marsh                  1
# Mandeep Singh             1
# Mustafizur Rahman         1
# PA Patel                  1
# PC Valthaty               1
# R Vinay Kumar             1
# SC Ganguly                1
# SE Marsh                  1
# SK Raina                  2
# SK Trivedi                1
# SL Malinga                1
# UT Yadav                  1
# V Kohli                   1
# V Sehwag                  2
# WP Saha                   1
# YK Pathan                 2
